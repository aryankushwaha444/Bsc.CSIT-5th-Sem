# %%
import matplotlib.pyplot as plt

# Sample data
sizes = [4, 8, 12, 16, 20]
dp_times = [0.0001, 0.0002, 0.0004, 0.0007, 0.0012]  # Replace with actual times
bt_times = [0.0002, 0.0005, 0.0015, 0.005, 0.02]     # Replace with actual times

plt.plot(sizes, dp_times, label='Dynamic Programming', marker='o')
plt.plot(sizes, bt_times, label='Backtracking', marker='s')

plt.xlabel('Number of Items (n)')
plt.ylabel('Execution Time (seconds)')
plt.title('0-1 Knapsack Dynamic Programming vs Backtracking')
plt.legend()

plt.show()
